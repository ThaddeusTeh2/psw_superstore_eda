# %% [markdown]
# ## EDA of the Dataset
# ---

# %%
## collaborators:
# - @FSS09524
# - @FCS11424

# %% [markdown]
# #### Importing libraries

# %%
# For dataset manipulation
import pandas as pd
# For mathematical requirements (if any)
import numpy as np
# For graphical visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Reading the dataset

# %%
df = pd.read_csv("superstore.csv", encoding='ISO-8859-1')

# %% [markdown]
# #### Retrieving the first 5 rows of the dataset

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# #### Total rows and columns of the dataset

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# #### Dropping irrelevant columns

# %%
# Deus handiwork :D
columns_to_drop = [
    "Row ID",
    # "Order ID",
    "Customer ID",
    "Customer Name",
    "Postal Code",
    "Product ID",
    "Product Name"
]

for col in columns_to_drop:
    if col in df.columns:
        df = df.drop(col, axis=1)

df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode    Segment  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class   Consumer
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   Consumer
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class  Corporate
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class   Consumer
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   Consumer
#
#          Country             City       State Region         Category  \
# 0  United States        Henderson    Kentucky  South        Furniture
# 1  United States        Henderson    Kentucky  South        Furniture
# 2  United States      Los Angeles  California   West  Office Supplies
# 3  United States  Fort Lauderdale     Florida  South        Furniture
# 4  United States  Fort Lauderdale     Florida  South  Office Supplies
#
#   Sub-Category     Sales  Quantity  Discount    Profit
# 0    Bookcases  261.9600         2      0.00   41.9136
# ...

# %% [markdown]
# #### Rechecking the dataset after dropping the columns

# %%
df.shape
# Out:
# (9994, 15)

# %% [markdown]
# #### General characteristics of the refined dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9994 non-null   object
#  1   Order Date    9994 non-null   object
#  2   Ship Date     9994 non-null   object
#  3   Ship Mode     9994 non-null   object
#  4   Segment       9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   State         9994 non-null   object
#  8   Region        9994 non-null   object
#  9   Category      9994 non-null   object
#  10  Sub-Category  9994 non-null   object
#  11  Sales         9994 non-null   float64
#  12  Quantity      9994 non-null   int64
#  13  Discount      9994 non-null   float64
#  14  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Statistical characteristics of the refined dataset

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# #### Checking null values per column

# %%
df.isna().sum()
# Out:
# Order ID        0
# Order Date      0
# Ship Date       0
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### Checking unique values per column

# %%
#Deus checkin unique values in categorical cols
columns_to_check = [
    "Ship Mode",
    "Segment",
    "Country",
    "City",
    "State",
    "Region",
    "Category",
    "Sub-Category"
]

for col in columns_to_check:
    if col in df.columns:
        print(f"Unique vals in '{col}':")
        print(df[col].unique())
        print("-" * 20)
# Out:
# Unique vals in 'Ship Mode':
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# --------------------
# Unique vals in 'Segment':
# ['Consumer' 'Corporate' 'Home Office']
# --------------------
# Unique vals in 'Country':
# ['United States']
# --------------------
# Unique vals in 'City':
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
# ...

# %% [markdown]
# #### Checking full row duplicates

# %%
duplicates_df = df[df.duplicated(subset=[col], keep=False)]

duplicates_df.to_csv("duplicates.csv", index=False)

# %%
duplicates_df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode    Segment  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class   Consumer
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class   Consumer
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class  Corporate
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class   Consumer
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class   Consumer
# ...              ...         ...         ...             ...        ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class   Consumer
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class   Consumer
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class   Consumer
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class   Consumer
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class   Consumer
#
#             Country             City       State Region         Category  \
# ...

# %% [markdown]
# #### As you can see from the refined dataset above, for example the first 2 rows, the order ID is similar as well as the category of the product purchases. However, the sub category is different. Hence, there is no point in making checks for duplicates.
#
# ---

# %%
# Deus handiwork :D
columns_to_drop = [
    "Row ID",
    "Order ID",
    "Customer ID",
    "Customer Name",
    "Postal Code",
    "Product ID",
    "Product Name"
]

for col in columns_to_drop:
    if col in df.columns:
        df = df.drop(col, axis=1)

df.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment        Country  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer  United States
# 1   11/8/2016  11/11/2016    Second Class   Consumer  United States
# 2   6/12/2016   6/16/2016    Second Class  Corporate  United States
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  United States
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  United States
#
#               City       State Region         Category Sub-Category     Sales  \
# 0        Henderson    Kentucky  South        Furniture    Bookcases  261.9600
# 1        Henderson    Kentucky  South        Furniture       Chairs  731.9400
# 2      Los Angeles  California   West  Office Supplies       Labels   14.6200
# 3  Fort Lauderdale     Florida  South        Furniture       Tables  957.5775
# 4  Fort Lauderdale     Florida  South  Office Supplies      Storage   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Parsing the dates

# %%
df = pd.read_csv("superstore.csv", encoding='ISO-8859-1', parse_dates=["Order Date", "Ship Date"])

# Save back to CSV (overwrite or new file)
df.to_csv("superstore_parsed_dates.csv", index=False)
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# i dw these bruh
columns_to_drop = [
    "Row ID",
    "Order ID",
    "Customer ID",
    "Customer Name",
    "Postal Code",
    "Product ID",
    "Product Name"
]

for col in columns_to_drop:
    if col in df.columns:
        df = df.drop(col, axis=1)

df.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Segment        Country  \
# 0 2016-11-08 2016-11-11    Second Class   Consumer  United States
# 1 2016-11-08 2016-11-11    Second Class   Consumer  United States
# 2 2016-06-12 2016-06-16    Second Class  Corporate  United States
# 3 2015-10-11 2015-10-18  Standard Class   Consumer  United States
# 4 2015-10-11 2015-10-18  Standard Class   Consumer  United States
#
#               City       State Region         Category Sub-Category     Sales  \
# 0        Henderson    Kentucky  South        Furniture    Bookcases  261.9600
# 1        Henderson    Kentucky  South        Furniture       Chairs  731.9400
# 2      Los Angeles  California   West  Office Supplies       Labels   14.6200
# 3  Fort Lauderdale     Florida  South        Furniture       Tables  957.5775
# 4  Fort Lauderdale     Florida  South  Office Supplies      Storage   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# 1         3      0.00  219.5820
# ...

# %% [markdown]
# #### Bar Chart of Sales by Category (Numbers)

# %%
# Group sales by category
sales_by_category = df.groupby("Category")["Sales"].sum().sort_values()

# Plot
plt.figure(figsize=(8,6))
sales_by_category.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Total Sales by Category", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Total Sales ($)", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Technology has the highest sales among all categories

# Furniture is the second highest

# Office Supplies has the lowest sales

# %% [markdown]
# #### Pie chart of customer segments

# %%
# Count number of records per Segment
segment_counts = df["Segment"].value_counts()

# Pie chart
plt.figure(figsize=(6,6))
plt.pie(
    segment_counts,
    labels=segment_counts.index,
    autopct="%1.1f%%",    
    startangle=120,          # rotate for better layout
)
plt.title("Customer Segments Distribution", fontsize=14, fontweight="bold")
plt.show()

# Consumer segment has the highest sales

# Corporate comes next

# Home Office has the lowest sales

# %% [markdown]
# #### Pie chart of ship mode

# %%
# Count number of records per Segment
segment_counts = df["Ship Mode"].value_counts()

# Pie chart
plt.figure(figsize=(6,6))
plt.pie(
    segment_counts,
    labels=segment_counts.index,
    autopct="%1.1f%%",      
    startangle=120,        
)
plt.title("Ship Mode Distribution", fontsize=14, fontweight="bold")
plt.show()

# Standard Class is the most used shipping mode

# Second Class and First Class are used less

# Same Day shipping is the least used

# %% [markdown]
# #### Pie chart of sales by category (Percentage)

# %%
# Aggregate total sales by Category
sales_by_category = df.groupby("Category")["Sales"].sum()

# Pie chart
plt.figure(figsize=(6,6))
plt.pie(
    sales_by_category,
    labels=sales_by_category.index,
    autopct="%1.1f%%",       
    startangle=120,       
)

plt.title("Total Sales by Category", fontsize=14, fontweight="bold")
plt.show()

# Technology has the highest sales

# Furniture is the second highest

# Office Supplies has the lowest sales

# %% [markdown]
# #### Grouped bar chart of orders by category and sub-category

# %%
df = pd.read_csv("superstore_feature_engineered.csv", encoding='ISO-8859-1')

# %%
# Count number of orders for each Category + Sub-Category
subcat_counts = df.groupby(["Category", "Sub-Category"]).size().reset_index(name="Order Count")

# Plot
plt.figure(figsize=(12,6))
for category in subcat_counts["Category"].unique():
    subset = subcat_counts[subcat_counts["Category"] == category]
    plt.bar(subset["Sub-Category"], subset["Order Count"], label=category)

plt.title("Orders by Category and Sub-Category", fontsize=16, fontweight="bold")
plt.xlabel("Sub-Category", fontsize=12)
plt.ylabel("Number of Orders", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.legend(title="Category")
plt.tight_layout()
plt.show()

# Each main category is broken down into sub-categories

# Office Supplies has the highest number of orders overall 

# Technology and Furniture have fewer orders compared to Office Supplies

# %% [markdown]
# # PROFIT VS CATEGORIES/SEGMENTS

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Category", y="Profit", estimator=sum, ci=None)
plt.title("Total Profit by Category")
plt.show()

plt.figure(figsize=(12,6))
sns.barplot(data=df, x="Sub-Category", y="Profit", estimator=sum, ci=None, order=df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False).index)
plt.xticks(rotation=45)
plt.title("Total Profit by Sub-Category")
plt.show()

plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Segment", y="Profit", estimator=sum, ci=None)
plt.title("Total Profit by Segment")
plt.show()

# Technology gives the highest profit

# Office Supplies also gives good profit

# Furniture has the lowest profit and sometimes losses
# Out:
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/4155999918.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Category", y="Profit", estimator=sum, ci=None)
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/4155999918.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Sub-Category", y="Profit", estimator=sum, ci=None, order=df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False).index)
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/4155999918.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Segment", y="Profit", estimator=sum, ci=None)

# %% [markdown]
# # PROFIT VS REGIONS/STATES

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Region", y="Profit", estimator=sum, ci=None)
plt.title("Total Profit by Region")
plt.show()

plt.figure(figsize=(12,6))
top_states = df.groupby("State")["Profit"].sum().sort_values(ascending=False).head(15).index
sns.barplot(data=df[df["State"].isin(top_states)], x="State", y="Profit", estimator=sum, ci=None, order=top_states)
plt.xticks(rotation=45)
plt.title("Top 15 States by Total Profit")
plt.show()

plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="Region_Category", y="Profit")
plt.xticks(rotation=45)
plt.title("Profit Distribution by Region-Category Combination")
plt.show()

# West region makes the highest profit

# East also gives good profit

# South has lower profit

# Central is the least profitable and sometimes shows losses
# Out:
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/70205545.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Region", y="Profit", estimator=sum, ci=None)
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/70205545.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df[df["State"].isin(top_states)], x="State", y="Profit", estimator=sum, ci=None, order=top_states)

# %% [markdown]
# # PROFIT VS DISCOUNT

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Discount", y="Profit", hue="Category", alpha=0.6)
plt.title("Discount vs Profit (colored by Category)")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Has_Discount", y="Profit")
plt.title("Profit Distribution: With vs Without Discount")
plt.show()

plt.figure(figsize=(8,5))
sns.lineplot(data=df, x="Discount_x_Quantity", y="Profit", ci=None)
plt.title("Profit vs Discount * Quantity")
plt.show()

# When discount is low, profit is mostly positive

# As discount increases, profit goes down

# Very high discounts often lead to losses
# Out:
# /var/folders/04/wngkl13j3hj0s528zj5lpnj00000gn/T/ipykernel_38767/557033448.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="Discount_x_Quantity", y="Profit", ci=None)

# %% [markdown]
# # PROFIT VS SALES / QUANTITY

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Sales", y="Profit", alpha=0.6)
plt.xscale("log")
plt.yscale("symlog")
plt.title("Sales vs Profit (Log-Scaled)")
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Quantity", y="Profit", alpha=0.6)
plt.title("Quantity vs Profit")
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Price_Per_Unit", y="Profit_Per_Unit", alpha=0.6)
plt.title("Price per Unit vs Profit per Unit")
plt.show()

# When sales or quantity are small, profit is also small but mostly positive

# With medium sales or quantity, profit can be higher

# At very high sales or very large quantities, many orders still show losses because of big discounts

# %% [markdown]
# # PROFIT OVER TIME

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=df.groupby("Order_Year")["Profit"].sum().reset_index(), x="Order_Year", y="Profit")
plt.title("Total Profit by Year")
plt.show()

plt.figure(figsize=(10,5))
sns.lineplot(data=df.groupby("Order_Month")["Profit"].sum().reset_index(), x="Order_Month", y="Profit")
plt.title("Total Profit by Month (All Years Combined)")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Order_Quarter", y="Profit")
plt.title("Profit Distribution by Quarter")
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(data=df, x="Order_DayOfWeek_Name", y="Profit", order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
plt.title("Profit by Day of Week")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Is_Holiday_Season", y="Profit")
plt.title("Profit Distribution: Holiday Season vs Non-Holiday")
plt.show()

# Profit increased steadily from 2014 to 2017

# Within each year, profit goes up and down by month

# December has the highest profit, while some months like April and July are lower

# Overall: Profit is growing year by year, with clear seasonal peaks in December

# %% [markdown]
# # PROFITABILITY METRICS

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Profit_Margin"], bins=30, kde=True)
plt.title("Distribution of Profit Margins")
plt.show()

plt.figure(figsize=(10,6))
sns.violinplot(data=df, x="Category", y="Profit_Margin")
plt.title("Profit Margin by Category")
plt.show()

# Most orders have positive profit margins between 0 and 0.5

# Some orders show negative margins (losses), with a few very large losses

# By category:
# Technology → generally higher margins but more variation
# Office Supplies → margins are stable but smaller
# Furniture → widest spread, with many orders in losses

# %% [markdown]
# # CORRELATION HEATMAP

# %%
plt.figure(figsize=(10,8))
corr = df[["Profit","Sales","Quantity","Discount","Profit_Margin","Profit_Per_Unit","Sales_Per_Quantity"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap of Key Metrics")
plt.show()

# Discount strongly reduces Profit Margin

# Sales and quantity alone don’t guarantee profit

# Profitability is best explained by discount and margins, not just sales volume
